# %% [markdown]
# <a href="https://colab.research.google.com/github/benlamsaddaqnassrallahencg-web/DS2025/blob/main/Analyse_Compte_rendu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install kagglehub pandas

import kagglehub
import os
import pandas as pd

# Télécharger la dataset
dataset_path = kagglehub.dataset_download("ayeshaseherr/student-performance")
print("Dataset téléchargée dans :", dataset_path)

# Trouver automatiquement un fichier CSV
csv_file = None
for root, dirs, files in os.walk(dataset_path):
    for f in files:
        if f.lower().endswith(".csv"):
            csv_file = os.path.join(root, f)
            break
    if csv_file:
        break

if not csv_file:
    raise FileNotFoundError("Aucun fichier CSV trouvé dans la dataset.")

print("CSV détecté :", csv_file)

# Charger dans Pandas
df = pd.read_csv(csv_file)

print("First 5 records:")
print(df.head())
# pip install kagglehub pandas

import kagglehub
import os
import pandas as pd

# Télécharger la dataset
dataset_path = kagglehub.dataset_download("ayeshaseherr/student-performance")
print("Dataset téléchargée dans :", dataset_path)

# Trouver automatiquement un fichier CSV
csv_file = None
for root, dirs, files in os.walk(dataset_path):
    for f in files:
        if f.lower().endswith(".csv"):
            csv_file = os.path.join(root, f)
            break
    if csv_file:
        break

if not csv_file:
    raise FileNotFoundError("Aucun fichier CSV trouvé dans la dataset.")

print("CSV détecté :", csv_file)

# Charger dans Pandas
df = pd.read_csv(csv_file)

print("First 5 records:")
print(df.head())
# Out:
# Using Colab cache for faster access to the 'student-performance' dataset.
# Dataset téléchargée dans : /kaggle/input/student-performance
# CSV détecté : /kaggle/input/student-performance/StudentPerformanceFactors.csv
# First 5 records:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# ...
